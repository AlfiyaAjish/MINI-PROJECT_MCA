# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/laptop_data (1).csv")
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.head(100)
# Out:
#     Unnamed: 0 Company            TypeName  Inches  \
# 0            0   Apple           Ultrabook    13.3
# 1            1   Apple           Ultrabook    13.3
# 2            2      HP            Notebook    15.6
# 3            3   Apple           Ultrabook    15.4
# 4            4   Apple           Ultrabook    13.3
# ..         ...     ...                 ...     ...
# 95          95    Acer  2 in 1 Convertible    13.3
# 96          96    Dell            Notebook    15.6
# 97          97    Dell            Notebook    15.6
# 98          98    Asus            Notebook    15.6
# 99          99      HP              Gaming    15.6
#
#                              ScreenResolution                          Cpu  \
# 0          IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 1                                    1440x900         Intel Core i5 1.8GHz
# 2                           Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['Price'])
plt.show()

# %%
sns.distplot(df['Price'],color='red')
plt.show()
# Out:
# <ipython-input-12-db7a8c2c717b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],color='red')

# %%
df['Company'].value_counts().plot(kind='bar')
plt.ylabel('count')
plt.show()

# %%
sns.barplot(x=df['Company'],y=df['Price'],palette='husl')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-14-75909787f153>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Company'],y=df['Price'],palette='husl')

# %%
df['TypeName'].value_counts().plot(kind='bar')
plt.ylabel('count')
plt.show()
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
sns.barplot(x=df['TypeName'],y=df['Price'],palette='autumn')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-16-e88fba37b07e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['TypeName'],y=df['Price'],palette='autumn')

# %%
sns.distplot(df['Inches'])
plt.show()
# Out:
# <ipython-input-17-dff43b403089>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 403     Acer  Notebook    15.6            Full HD 1920x1080
# 518       HP  Notebook    15.6            Full HD 1920x1080
# 230     Asus  Notebook    15.6                     1366x768
# 1218  Lenovo    Gaming    15.6  IPS Panel Full HD 1920x1080
# 313     Acer  Notebook    15.6            Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 403   Intel Core i7 7700HQ 2.8GHz    8             256GB SSD
# 518    Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 230    Intel Core i3 7100U 2.4GHz    4               1TB HDD
# 1218  Intel Core i7 6700HQ 2.6GHz    8  128GB SSD +  1TB HDD
# 313     AMD A8-Series 7410 2.2GHz    8             256GB SSD
#
#                                  Gpu       OpSys  Weight       Price  \
# 403          Nvidia GeForce GTX 1050       Linux    2.50  46833.1200
# 518             Nvidia GeForce 930MX  Windows 10    2.04  47365.9200
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
plt.ylabel('count')
plt.show()

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
plt.show()

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['IPS'].value_counts().plot(kind='bar')
plt.ylabel('count')
plt.show()

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
new=df['ScreenResolution'].str.split('x',expand=True)
df['x_res']=new[0]
df['y_res']=new[1]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['x_res']=df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)')
df['x_res']=df['x_res'].apply(lambda x:x[0])
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   object
#  14  y_res             1303 non-null   object
# dtypes: float64(3), int32(1), int64(2), object(9)
# ...

# %%
df['x_res']=df['x_res'].astype(int)
df['y_res']=df['y_res'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   int64
#  14  y_res             1303 non-null   int64
# dtypes: float64(3), int32(1), int64(4), object(7)
# ...

# %%
numeric_data = df.select_dtypes(include=['number'])
numeric_data .corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi']=((df['x_res']**2)+(df['y_res']**2))**0.5/df['Inches']
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS  x_res  y_res         ppi
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# ...

# %%
numeric_data = df.select_dtypes(include=['number'])
numeric_data .corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# x_res          0.556529
# y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['x_res','y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi
# 0   71378.6832            0    1  226.983005
# 1   47895.5232            0    0  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi       Cpu Name
# 0   71378.6832            0    1  226.983005  Intel Core i5
# 1   47895.5232            0    0  127.677940  Intel Core i5
# ...

# %%
def processor(cpu):
  if cpu=='Intel Core i7' or cpu=='Intel Core i5' or cpu=='Intel Core i3':
    return cpu
  else:
    if cpu.split()[0]=='Intel':
      return 'Other Intel Processor'
    else:
      return 'AMD Processor'

# %%
df['Cpu brand']=df['Cpu Name'].apply(processor)

# %%
df.head()
df.sample(10)
# Out:
#      Company     TypeName  Inches                                   Cpu  Ram  \
# 11        HP     Notebook    15.6              Intel Core i3 6006U 2GHz    4
# 952  Toshiba     Notebook    13.3            Intel Core i5 6200U 2.3GHz    8
# 691   Lenovo     Notebook    14.0            Intel Core i5 7200U 2.5GHz    4
# 514   Xiaomi     Notebook    15.6            Intel Core i7 8550U 1.8GHz   16
# 722   Lenovo    Ultrabook    14.0            Intel Core i5 7200U 2.5GHz    8
# 662   Lenovo     Notebook    15.6            Intel Core i5 6200U 2.3GHz    4
# 204     Dell  Workstation    15.6           Intel Xeon E3-1505M V6 3GHz   16
# 818     Dell       Gaming    17.3           Intel Core i7 7700HQ 2.8GHz   16
# 601       HP     Notebook    15.6            Intel Core i3 7100U 2.4GHz    4
# 443   Lenovo     Notebook    15.6  Intel Pentium Quad Core N4200 1.1GHz    4
#
#                    Memory                      Gpu       OpSys  Weight  \
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
plt.ylabel='count'

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
# 3   Apple  Ultrabook    15.4   16            512GB SSD
# 4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
df['Ram'].value_counts()
# Out:
# Ram
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)
df["first"]= new[0]
df["first"]=df["first"].str.strip()
df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df['first']=df['first'].str.replace(r'\D', '')
df['second']=df['second'].str.replace(r'\D', '')
df["second"].fillna("0", inplace = True)
# Out:
# <ipython-input-52-76f66f5670d4>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0", inplace = True)

# %%
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df['first']=df['first'].str.replace(r'\D', '', regex=True)

# %%
df["first"] = df["first"].astype(int)

# %%
df['second']=df['second'].str.replace(r'\D', '', regex=True)

# %%
df["second"] = df["second"].astype(int)

# %%
df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])

# %%
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])

# %%
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])

# %%
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

# %%
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(10)
# Out:
#      Company            TypeName  Inches  Ram            Memory  \
# 1151      HP            Notebook    15.6    4           500 HDD
# 705     Dell            Notebook    15.6    8           256 SSD
# 317   Lenovo            Notebook    13.3    4  16 Flash Storage
# 793   Lenovo  2 in 1 Convertible    15.6    8           256 SSD
# 124     Acer            Notebook    15.6    4           256 SSD
# 801     Asus            Notebook    15.6    8           256 SSD
# 833   Lenovo            Notebook    14.0    8           256 SSD
# 206     Dell            Notebook    15.6    6          1000 HDD
# 727     Dell  2 in 1 Convertible    13.3    4          1000 HDD
# 696   Lenovo  2 in 1 Convertible    14.0   16           512 SSD
#
#                          Gpu       OpSys  Weight      Price  Touchscreen  IPS  \
# 1151  AMD Radeon R2 Graphics  Windows 10    1.86  15824.160            0    0
# 705    Intel HD Graphics 620  Windows 10    2.18  42357.600            0    0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
numeric_data = df.select_dtypes(include=['number'])
numeric_data .corr()['Price']
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Inches       1303 non-null   float64
#  3   Ram          1303 non-null   int32
#  4   Gpu          1303 non-null   object
#  5   OpSys        1303 non-null   object
#  6   Weight       1303 non-null   float64
#  7   Price        1303 non-null   float64
#  8   Touchscreen  1303 non-null   int64
#  9   IPS          1303 non-null   int64
#  10  ppi          1303 non-null   float64
#  11  Cpu brand    1303 non-null   object
#  12  HDD          1303 non-null   int64
#  13  SSD          1303 non-null   int64
# dtypes: float64(4), int32(1), int64(4), object(5)
# memory usage: 137.6+ KB

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram                           Gpu  OpSys  \
# 0   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    13.3    8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    15.6    8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook    15.4   16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS         ppi      Cpu brand  HDD  SSD  \
# 0    1.37   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1    1.34   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2    1.86   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3    1.83  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4    1.37   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# ...

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    13.3    8  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    13.3    8  macOS    1.34   47895.5232            0
# 2      HP   Notebook    15.6    8  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook    15.4   16  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    13.3    8  macOS    1.37   96095.8080            0
#
#    IPS         ppi      Cpu brand  HDD  SSD Gpu brand
# 0    1  226.983005  Intel Core i5    0  128     Intel
# 1    0  127.677940  Intel Core i5    0    0     Intel
# 2    0  141.211998  Intel Core i5    0  256     Intel
# 3    1  220.534624  Intel Core i7    0  512       AMD
# 4    1  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    13.3    8  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    13.3    8  macOS    1.34   47895.5232            0
# 2      HP   Notebook    15.6    8  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook    15.4   16  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    13.3    8  macOS    1.37   96095.8080            0
#
#    IPS         ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0    1  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1    0  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2    0  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3    1  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4    1  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# <ipython-input-84-05ee4c8848be>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
numeric_data = df.select_dtypes(include=['number'])
numeric_data .corr()['Price']
# Out:
# Inches         0.067329
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
numeric_data = df.select_dtypes(include=['number'])
sns.heatmap(numeric_data.corr())
# Out:
# <Axes: >

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-88-c1a82a4801f0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Inches  Ram  Weight  Touchscreen  IPS  \
# 0      Apple           Ultrabook    13.3    8    1.37            0    1
# 1      Apple           Ultrabook    13.3    8    1.34            0    0
# 2         HP            Notebook    15.6    8    1.86            0    0
# 3      Apple           Ultrabook    15.4   16    1.83            0    1
# 4      Apple           Ultrabook    13.3    8    1.37            0    1
# ...      ...                 ...     ...  ...     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4    1.80            1    1
# 1299  Lenovo  2 in 1 Convertible    13.3   16    1.30            1    1
# 1300  Lenovo            Notebook    14.0    2    1.50            0    0
# 1301      HP            Notebook    15.6    6    2.19            0    0
# 1302    Asus            Notebook    15.6    4    2.20            0    0
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Inches  Ram  Weight  Touchscreen  IPS  \
# 183   Toshiba            Notebook    15.6    8    2.00            0    0
# 1141      MSI              Gaming    15.6    8    2.40            0    0
# 1049     Asus             Netbook    11.6    4    1.20            0    0
# 1020     Dell  2 in 1 Convertible    15.6    4    2.08            1    1
# 878      Dell            Notebook    15.6    4    2.18            0    0
# ...       ...                 ...     ...  ...     ...          ...  ...
# 466      Acer            Notebook    15.6    4    2.20            0    0
# 299      Asus           Ultrabook    15.6   16    1.63            0    0
# 493      Acer            Notebook    15.6    8    2.20            0    0
# 527    Lenovo            Notebook    15.6    8    2.20            0    0
# 1193    Apple           Ultrabook    12.0    8    0.92            0    1
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Inches       1302 non-null   float64
#  3   Ram          1302 non-null   int32
#  4   Weight       1302 non-null   float64
#  5   Price        1302 non-null   float64
#  6   Touchscreen  1302 non-null   int64
#  7   IPS          1302 non-null   int64
#  8   ppi          1302 non-null   float64
#  9   Cpu brand    1302 non-null   object
#  10  HDD          1302 non-null   int64
#  11  SSD          1302 non-null   int64
#  12  Gpu brand    1302 non-null   object
#  13  os           1302 non-null   object
# dtypes: float64(4), int32(1), int64(4), object(5)
# memory usage: 147.5+ KB

# %%
 step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=4,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=25)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8931818399905426
# MAE 0.15105222860487258

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-630348889997> in <cell line: 2>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       3 print(cm)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     340     (np.int64(0), np.int64(2), np.int64(1), np.int64(1))
#     341     """
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have y_test and y_pred available

plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-a6b52a32160c> in <cell line: 7>()
#       5 plt.scatter(y_test, y_pred)
#       6 plt.xlabel("Actual Values")
# ----> 7 plt.ylabel("Predicted Values")
#       8 plt.title("Actual vs. Predicted Values")
#       9 plt.show()
#
# TypeError: 'str' object is not callable

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# Assuming y_test and y_pred are continuous variables

# Define the number of bins
num_bins = 5

# Discretize y_test and y_pred into bins
y_test_bins = np.digitize(y_test, np.linspace(min(y_test), max(y_test), num_bins))
y_pred_bins = np.digitize(y_pred, np.linspace(min(y_pred), max(y_pred), num_bins))

# Create the confusion matrix
cm = confusion_matrix(y_test_bins, y_pred_bins)
print(cm)
# Out:
# [[19  2  0  0  0]
#  [ 9 38  7  0  0]
#  [ 0 13 61  7  0]
#  [ 0  0  9 29  1]
#  [ 0  0  1  0  0]]

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11]) # Replace 'sparse' with 'sparse_output'
],remainder='pas
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
#   File "<ipython-input-98-3642de77146e>", line 11
#     ],remainder='pas
#                 ^
# SyntaxError: unterminated string literal (detected at line 11)

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
#import pickle
import numpy as np


# Get user input for laptop features
company = input("Enter the laptop's company: ")
typename = input("Enter the laptop's typename: ")
inches= float(input("Enter the laptop's inches: "))
ram = int(input("Enter the RAM size (in GB): "))
weight = float(input("Enter the weight (in kg): "))
touchscreen = int(input("Is it a touchscreen? (1 for Yes, 0 for No): "))
ips = int(input("Does it have an IPS display? (1 for Yes, 0 for No): "))
ppi = float(input("Enter the PPI value: "))
cpu_brand = input("Enter the CPU brand: ")
hdd = int(input("Enter the HDD size (in GB): "))
ssd = int(input("Enter the SSD size (in GB): "))
gpu_brand = input("Enter the GPU brand: ")
os = input("Enter the operating system: ")

# Create a dictionary with the input features
query = np.array([[company, typename, inches, ram, weight, touchscreen, ips, ppi, cpu_brand, hdd, ssd, gpu_brand, os]])

# Make the prediction using the loaded model
prediction = pipe.predict(query)[0]

# Print the predicted price
print("The predicted price of the laptop is:", np.exp(prediction))
# Out:
# Enter the laptop's company: HP
# Enter the laptop's typename: Ultrabook
# Enter the laptop's inches: 15.6
# Enter the RAM size (in GB): 8
# Enter the weight (in kg): 1.7
# Is it a touchscreen? (1 for Yes, 0 for No): 0
# Does it have an IPS display? (1 for Yes, 0 for No): 1
# Enter the PPI value: 146.14
# Enter the CPU brand: Intel Core i5
# Enter the HDD size (in GB): 0
# Enter the SSD size (in GB): 512
# Enter the GPU brand: Intel
# Enter the operating system: Windows
# The predicted price of the laptop is: 64157.18267032955
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
